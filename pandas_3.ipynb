# %% [markdown]
# <a href="https://colab.research.google.com/github/gmrampe/Data_Analysis/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("movies.csv")
directors = pd.read_csv("directors.csv")

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
movies.drop(columns = ["Unnamed: 0"] , inplace = True)

# %%
directors.drop(columns = ["Unnamed: 0"] , inplace = True)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
data = movies.merge(directors, how = "left", left_on = "director_id", right_on = "id")

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.drop(columns = ["id_y"], inplace = True)

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  gender         1341 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 160.2+ KB

# %%
data.describe()
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1465.000000  1465.000000  1465.000000
# mean    1146.396587  5040.192491  2002.615017
# std     1578.077438   258.059631     8.680141
# min        1.000000  4762.000000  1976.000000
# 25%      216.000000  4845.000000  1998.000000
# ...

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
data["revenue"] = (data["revenue"]/1000000).round(2)
data["budget"] = (data["budget"]/1000000).round(2)

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# 2         4764  2015   Oct    Monday         Sam Mendes   Male
# ...

# %%
data.loc[data["vote_average"] > 7]
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 3     43600  250.00         112  1084.94
# 14    43616  250.00         120   956.02
# 16    43619  250.00          94   958.40
# 19    43622  200.00         100  1845.03
# ...     ...     ...         ...      ...
# 1456  48321    0.01          20     7.00
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# 19                                      Titanic           7.5        7562
# ...

# %%
data['year'].isin([2015, 2016, 2012])
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: year, Length: 1465, dtype: bool

# %%
df2 = data.loc[data["vote_average"] > 7]

# %%
df2.head()
# Out:
#      id_x  budget  popularity  revenue  \
# 0   43597   237.0         150  2787.97
# 3   43600   250.0         112  1084.94
# 14  43616   250.0         120   956.02
# 16  43619   250.0          94   958.40
# 19  43622   200.0         100  1845.03
#
#                                         title  vote_average  vote_count  \
# 0                                      Avatar           7.2       11800
# 3                       The Dark Knight Rises           7.6        9106
# 14  The Hobbit: The Battle of the Five Armies           7.1        4760
# 16        The Hobbit: The Desolation of Smaug           7.6        4524
# 19                                    Titanic           7.5        7562
#
#     director_id  year month        day      director_name gender
# 0          4762  2009   Dec   Thursday      James Cameron   Male
# 3          4765  2012   Jul     Monday  Christopher Nolan   Male
# 14         4777  2014   Dec  Wednesday      Peter Jackson   Male
# ...

# %%
#display the title and director_name of the movies with vote_avg > 7

# %%
df2.loc[ : , ["title", "director_name"] ]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
data.loc[data["vote_average"] > 7 , ["title", "director_name"]]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
#Display only those movies where the vote_avg > 7 and they have been released in or after 2015

# %%
data.loc[data["vote_average"] > 7 and data["year"] >= 2015]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-89f2d8869e9c> in <cell line: 1>()
# ----> 1 data.loc[data["vote_average"] > 7 and data["year"] >= 2015]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data.loc[ (data["vote_average"] > 7) and (data["year"] >= 2015)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ab1809693a61> in <cell line: 1>()
# ----> 1 data.loc[ (data["vote_average"] > 7) and (data["year"] >= 2015)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
'''
& --> and
| --> or
'''

# %%
data.loc[ (data["vote_average"] > 7) & (data["year"] >= 2015)]
# Out:
#        id_x  budget  popularity  revenue                    title  \
# 30    43641   190.0         102  1506.25                Furious 7
# 78    43724   150.0         434   378.86       Mad Max: Fury Road
# 106   43773   135.0         100   532.95             The Revenant
# 162   43867   108.0         167   630.16              The Martian
# 312   44128    75.0          48   108.15  The Man from U.N.C.L.E.
# 394   44281    44.0          68   155.76        The Hateful Eight
# 625   44770    35.0          53   194.56               The Intern
# 635   44784    40.0          48   165.48          Bridge of Spies
# 808   45194    30.0          65    91.71                 Southpaw
# 833   45293    28.0          61   201.63   Straight Outta Compton
# 839   45301    28.0          57   133.35            The Big Short
# 1344  47181     5.0          22    24.80                     Race
#
#       vote_average  vote_count  director_id  year month        day  \
# ...

# %%
#Display those rows where movie has been released on Fri or Sat

# %%
data.loc[(data["day"] == "Friday") | (data["day"] == "Saturday")]
# Out:
#        id_x  budget  popularity  revenue  \
# 1     43598  300.00         139   961.00
# 12    43614  380.00         135  1045.71
# 22    43627  200.00          35   783.77
# 25    43632  150.00          21   836.30
# 40    43656  200.00          45   769.65
# ...     ...     ...         ...      ...
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                             title  vote_average  vote_count  \
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 22                                   Spider-Man 2           6.7        4321
# 25            Transformers: Revenge of the Fallen           6.0        3138
# 40                                           2012           5.6        4903
# ...

# %%
#way2

data.loc[data["day"].isin(["Friday", "Saturday"])]
# Out:
#        id_x  budget  popularity  revenue  \
# 1     43598  300.00         139   961.00
# 12    43614  380.00         135  1045.71
# 22    43627  200.00          35   783.77
# 25    43632  150.00          21   836.30
# 40    43656  200.00          45   769.65
# ...     ...     ...         ...      ...
# 1457  48323    0.00           5     0.00
# 1458  48335    0.06          27     3.22
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                             title  vote_average  vote_count  \
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 22                                   Spider-Man 2           6.7        4321
# 25            Transformers: Revenge of the Fallen           6.0        3138
# 40                                           2012           5.6        4903
# ...

# %%
#apply()

# %%
#Task: Give encoding to the Genders: Male --> 0 , Female --> 1

# %%
def encode_gender(g):
  if g == "Male":
    return 0
  else:
    return 1

# %%
encode_gender("Male")
# Out:
# 0

# %%
data["gender"] = data["gender"].apply(encode_gender)

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender
# 0         4762  2009   Dec  Thursday      James Cameron       0
# 1         4763  2007   May  Saturday     Gore Verbinski       0
# 2         4764  2015   Oct    Monday         Sam Mendes       0
# ...

# %%
data[["revenue", "budget"]].apply(np.sum) #by default --> axis = 0
# Out:
# revenue    209867.04
# budget      70353.62
# dtype: float64

# %%
data[["revenue", "budget"]].apply(np.sum, axis = 1)
# Out:
# 0       3024.97
# 1       1261.00
# 2       1125.67
# 3       1334.94
# 4       1148.87
#          ...
# 1460       0.32
# 1461       3.18
# 1462       0.00
# 1463       0.00
# 1464       2.26
# Length: 1465, dtype: float64

# %%
#usecase

# %%
def calc_profit(df):
  profit = df["revenue"] - df["budget"]
  return profit

# %%
data["profit"] = data[["revenue", "budget"]].apply(calc_profit, axis = 1)

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %% [markdown]
# #### What is Grouping ?
#
# Simply it could be understood through the terms - Split, apply, combine
#
# <img src="https://learning.oreilly.com/api/v2/epubs/urn:orm:book:9781491912126/files/assets/pyds_03in01.png" height = 350/>
#
# 1. **Split**: **Breaking up and grouping** a DataFrame depending on the value of the specified key.
#
# 2. **Apply**: Computing **some functio**n, usually an **aggregate, transformation, or filtering**, within the individual groups.
#
# 3. **Combine**: **Merge the results** of these operations into an output array.
#
# > Note: All these steps are to understand the topic

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %%
data.groupby("director_name")

# %%
data.groupby("director_name").ngroups
# Out:
# 199

# %%
data.groupby("director_name").groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
data.groupby("director_name").get_group('Adam McKay')
# Out:
#       id_x  budget  popularity  revenue  \
# 176  43882   100.0          24   170.43
# 323  44151    72.5          12   162.97
# 366  44236    65.0          22   128.11
# 505  44503    50.0          38   173.65
# 839  45301    28.0          57   133.35
# 916  45443    26.0          29    90.57
#
#                                            title  vote_average  vote_count  \
# 176                               The Other Guys           6.1        1383
# 323  Talladega Nights: The Ballad of Ricky Bobby           6.2         491
# 366                                Step Brothers           6.5        1062
# 505            Anchorman 2: The Legend Continues           6.0         923
# 839                                The Big Short           7.3        2607
# 916        Anchorman: The Legend of Ron Burgundy           6.7        1493
#
#      director_id  year month        day director_name  gender  profit
# 176         4925  2010   Aug     Friday    Adam McKay       0   70.43
# ...

# %%
data.groupby("director_name")["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
data.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...

# %%
#Q- For every director, Find the first year and the last year in which they have directed a movie

# %%
data.groupby("director_name")["year"].min()
# Out:
# director_name
# Adam McKay                     2004
# Adam Shankman                  2001
# Alejandro González Iñárritu    2000
# Alex Proyas                    1994
# Alexander Payne                1999
#                                ...
# Wes Craven                     1984
# Wolfgang Petersen              1981
# Woody Allen                    1977
# Zack Snyder                    2004
# Zhang Yimou                    2002
# Name: year, Length: 199, dtype: int64

# %%
data.groupby("director_name")["year"].max()
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: year, Length: 199, dtype: int64

# %%
data.groupby("director_name")["year"].aggregate(["min", "max"])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
#Give the details of the movies by high budget directors

# %% [markdown]
# #### finding the details of the movies by high budget directors
# Lets assume,
# - high budget director -> any director with **atleast one movie with budget >100M**

# %%
data_dir_budget = data.groupby("director_name")["budget"].max().reset_index()
data_dir_budget.head()
# Out:
#                  director_name  budget
# 0                   Adam McKay   100.0
# 1                Adam Shankman    80.0
# 2  Alejandro González Iñárritu   135.0
# 3                  Alex Proyas   140.0
# 4              Alexander Payne    30.0

# %%
names = data_dir_budget.loc[data_dir_budget["budget"] > 100, "director_name"]

# %%
names
# Out:
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
# 15                Barry Sonnenfeld
#                   ...
# 185                      Tim Story
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
data.loc[data["director_name"].isin(names)]
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
#Display only those rows where budget > 100 M --> using groupby filter

# %%
data.groupby("director_name").filter(lambda df: df["budget"].max() > 100)
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1450  48267    0.40          33   100.00
# 1451  48268    0.20          13     4.51
# 1452  48274    0.00           5     2.61
# 1458  48335    0.06          27     3.22
# 1460  48363    0.00           3     0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
def check_risky(df):
  risky_flag = df["budget"] > df["revenue"].mean()
  df["risky"] = risky_flag
  return df

# %%
result = data.groupby("director_name").apply(check_risky)
# Out:
# <ipython-input-56-f982902ebf70>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   result = data.groupby("director_name").apply(check_risky)

# %%
result.head()
# Out:
#     id_x  budget  popularity  revenue  \
# 0  43597   237.0         150  2787.97
# 1  43598   300.0         139   961.00
# 2  43599   245.0         107   880.67
# 3  43600   250.0         112  1084.94
# 4  43602   258.0         115   890.87
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  gender   profit  \
# 0         4762  2009   Dec  Thursday      James Cameron       0  2550.97
# 1         4763  2007   May  Saturday     Gore Verbinski       0   661.00
# 2         4764  2015   Oct    Monday         Sam Mendes       0   635.67
# ...
