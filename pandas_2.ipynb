# %% [markdown]
# <a href="https://colab.research.google.com/github/gmrampe/Data_Analysis/blob/main/pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1:5, 1:4]
# Out:
#    year  population continent
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1967    11537966      Asia
# 4  1972    13079460      Asia

# %%
df.loc[1:5, ["country", "life_exp"]]
# Out:
#        country  life_exp
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088
# 5  Afghanistan    38.438

# %%
df.loc[1:5, "country" : "population"]
# Out:
#        country  year  population
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460
# 5  Afghanistan  1977    14880372

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[ [0,10,20] , [0, 2, 3] ]
# Out:
#         country  population continent
# 0   Afghanistan     8425333      Asia
# 10  Afghanistan    25268405      Asia
# 20      Albania     3326498    Europe

# %%
df.iloc[1:11:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
new_row = {'country':'India', 'year':2000, 'population':13500000, 'continent':'Asia', 'life_exp':37.08,  'gdp_cap':900.23}

# %%
df.append(new_row)
# Out:
# <ipython-input-14-98696000c65c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-98696000c65c> in <cell line: 1>()
# ----> 1 df.append(new_row)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9766         )
#    9767
# -> 9768         return self._append(other, ignore_index, verify_integrity, sort)
#    9769
#    9770     def _append(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9778             if isinstance(other, dict):
#    9779                 if not ignore_index:
# ...

# %%
df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-15-85c282e4af20>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row, ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# ...

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.append(new_row, ignore_index=True, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ddb84db54b9f> in <cell line: 1>()
# ----> 1 df.append(new_row, ignore_index=True, inplace = True)
#
# TypeError: DataFrame.append() got an unexpected keyword argument 'inplace'

# %%
df = df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-18-caa379dde9af>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2000    13500000      Asia    37.080  900.230000

# %%
df.loc[len(df.index)] = ['India', 2000, 13500000, "Asia", 37.08, 900.23] #appending a row at the end
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2000    13500000      Asia    37.080  900.230000
# 1705     India  2000    13500000      Asia    37.080  900.230000

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
#
# [1706 rows x 6 columns]

# %%
df.loc[len(df.index) - 1] = ['India', 2004, 13500000, "Asia", 37.08, 900.23] #modifying a row using loc
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2000    13500000      Asia    37.080  900.230000
# 1705     India  2004    13500000      Asia    37.080  900.230000

# %%
#record --> row
#feature, attribute --> column

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("country", axis = 1)
# Out:
#       year  population continent  life_exp     gdp_cap
# 0     1952     8425333      Asia    28.801  779.445314
# 1     1957     9240934      Asia    30.332  820.853030
# 2     1962    10267083      Asia    31.997  853.100710
# 3     1967    11537966      Asia    34.020  836.197138
# 4     1972    13079460      Asia    36.088  739.981106
# ...    ...         ...       ...       ...         ...
# 1701  1997    11404948    Africa    46.809  792.449960
# 1702  2002    11926563    Africa    39.989  672.038623
# 1703  2007    12311143    Africa    43.487  469.709298
# 1704  2000    13500000      Asia    37.080  900.230000
# 1705  2004    13500000      Asia    37.080  900.230000
#
# [1706 rows x 5 columns]

# %%
df.drop(3, axis = 0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2004    13500000      Asia    37.080  900.230000
#
# [1705 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop([1, 2, 4] , axis = 0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7     Afghanistan  1987    13867957      Asia    40.822  852.395945
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2004    13500000      Asia    37.080  900.230000
#
# [1703 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2000    13500000      Asia    37.080  900.230000
# 1705     India  2004    13500000      Asia    37.080  900.230000

# %%
df.loc[len(df.index)] = ['India',2000,13500000,"asia",37.08,900.23]
df.loc[len(df.index)] = ['Sri Lanka',2022,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['Sri Lanka',2022,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['India',2000,13500000,"asia",80.00,900.23]
df.tail(10)
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 1700   Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704      India  2000    13500000      Asia    37.080  900.230000
# 1705      India  2004    13500000      Asia    37.080  900.230000
# 1706      India  2000    13500000      asia    37.080  900.230000
# 1707  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1708  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1709      India  2000    13500000      asia    80.000  900.230000

# %%
#working with duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1705    False
# 1706    False
# 1707    False
# 1708     True
# 1709    False
# Length: 1710, dtype: bool

# %%
df_dup = df.loc[df.duplicated()]

# %%
df_dup
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1708  Sri Lanka  2022   130000000      asia      80.0    500.0

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2004    13500000      Asia    37.080  900.230000
# 1706        India  2000    13500000      asia    37.080  900.230000
# 1707    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1709        India  2000    13500000      asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.tail()
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1705      India  2004    13500000      Asia     37.08   900.23
# 1706      India  2000    13500000      asia     37.08   900.23
# 1707  Sri Lanka  2022   130000000      asia     80.00   500.00
# 1708  Sri Lanka  2022   130000000      asia     80.00   500.00
# 1709      India  2000    13500000      asia     80.00   900.23

# %%
df.drop_duplicates(keep = "first")
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2004    13500000      Asia    37.080  900.230000
# 1706        India  2000    13500000      asia    37.080  900.230000
# 1707    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1709        India  2000    13500000      asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.drop_duplicates(keep = "last")
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2004    13500000      Asia    37.080  900.230000
# 1706        India  2000    13500000      asia    37.080  900.230000
# 1708    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1709        India  2000    13500000      asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
life_exp = df["life_exp"]

# %%
#average life_exp in the given data

life_exp.mean()
# Out:
# 59.47116063157894

# %%
sum_life_exp = life_exp.sum()

# %%
life_exp.max()
# Out:
# 82.603

# %%
life_exp.min()
# Out:
# 23.599

# %%
#sort_values

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.sort_values(["life_exp"]) #df got sorted by life_exp in ascending order
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1710 rows x 6 columns]

# %%
df.sort_values(["life_exp"], ascending = False) #descending order
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1710 rows x 6 columns]

# %%
df.sort_values(["year", "life_exp"]) #same as SQL
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 1707         Sri Lanka  2022   130000000      asia    80.000    500.000000
# 1708         Sri Lanka  2022   130000000      asia    80.000    500.000000
#
# [1710 rows x 6 columns]

# %%
df.sort_values(["year", "life_exp"], ascending = [True, False])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1140       Norway  1952     3327728    Europe    72.670  10095.421720
# 684       Iceland  1952      147962    Europe    72.490   7267.688428
# 1080  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1464       Sweden  1952     7124673    Europe    71.860   8527.844662
# 408       Denmark  1952     4334000    Europe    70.780   9692.385245
# ...           ...   ...         ...       ...       ...           ...
# 1691       Zambia  2007    11746035    Africa    42.384   1271.211593
# 1043   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1463    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1707    Sri Lanka  2022   130000000      asia    80.000    500.000000
# 1708    Sri Lanka  2022   130000000      asia    80.000    500.000000
#
# [1710 rows x 6 columns]

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["Srinivas", "Prem", "Prashant"]})
users
# Out:
#    userid      name
# 0       1  Srinivas
# 1       2      Prem
# 2       3  Prashant

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users, msgs], axis = 0)
# Out:
#    userid      name        msg
# 0       1  Srinivas        NaN
# 1       2      Prem        NaN
# 2       3  Prashant        NaN
# 0       1       NaN        hmm
# 1       1       NaN       acha
# 2       2       NaN  theek hai
# 3       4       NaN       nice

# %%
pd.concat([users, msgs], axis = 0, ignore_index = True)
# Out:
#    userid      name        msg
# 0       1  Srinivas        NaN
# 1       2      Prem        NaN
# 2       3  Prashant        NaN
# 3       1       NaN        hmm
# 4       1       NaN       acha
# 5       2       NaN  theek hai
# 6       4       NaN       nice

# %%
pd.concat([users, msgs], axis = 1)
# Out:
#    userid      name  userid        msg
# 0     1.0  Srinivas       1        hmm
# 1     2.0      Prem       1       acha
# 2     3.0  Prashant       2  theek hai
# 3     NaN       NaN       4       nice

# %%
#joins

# %%
users
# Out:
#    userid      name
# 0       1  Srinivas
# 1       2      Prem
# 2       3  Prashant

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
#joins --> merge

# %%
users.merge(msgs, on = "userid") #inner join
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai

# %%
users.merge(msgs, on = "userid", how = "left")
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai
# 3       3  Prashant        NaN

# %%
users.merge(msgs, on = "userid", how = "right")
# Out:
#    userid      name        msg
# 0       1  Srinivas        hmm
# 1       1  Srinivas       acha
# 2       2      Prem  theek hai
# 3       4       NaN       nice

# %%
users.rename(columns = {"userid" : "id"}, inplace = True)
users
# Out:
#    id      name
# 0   1  Srinivas
# 1   2      Prem
# 2   3  Prashant

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users.merge(msgs, left_on = "id", right_on = "userid") #inner join
# Out:
#    id      name  userid        msg
# 0   1  Srinivas       1        hmm
# 1   1  Srinivas       1       acha
# 2   2      Prem       2  theek hai

# %%
#IMDB Dataset --> movies and directors

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 92.2MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 91.0MB/s]

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[10,30], 'B':[20,40], 'C':[30, 60]})
df2 = pd.DataFrame({'A':[10,30], 'C':[30, 60]})
df2.merge(df1, on = 'A', how = 'outer')
# Out:
#     A  C_x   B  C_y
# 0  10   30  20   30
# 1  30   60  40   60

# %%
movies = pd.read_csv("movies.csv")
directors = pd.read_csv("directors.csv")

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
movies.drop(columns = ["Unnamed: 0"],inplace=True)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
directors.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male
